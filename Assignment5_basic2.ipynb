# %% [raw]
#  Variable Manipulation:
# o Define variables to store a student's name, age, GPA, and list of subjects.
# o Convert age from years to months and display the result.
# o Concatenate and print a sentence using all the defined variables.

# %%
# 1.1 Define variables to store a student's name, age, GPA, and list of subjects. 

name = 'Renuka'
age = 20
GPA = 9.19
subject = ['Python', 'Java', 'C', 'C++']

# %%
# 1.2 Convert age from years to months and display the result.
age = 20 * 12
print(age,'Months')
# Out:
# 240 Months

# %%
# 1.3 Concatenate and print a sentence using all the defined variables.

name = 'Renuka'
age = 20
GPA = 9.19
subject = {'Python', 'Java', 'C', 'C++'}
print(f'My name is {name}. I am {age} years old. In last semester I secure {GPA} GPA. I learned multiple languages like {subject}.')
# Out:
# My name is Renuka. I am 20 years old. In last semester I secure 9.19 GPA. I learned multiple languages like {'C++', 'C', 'Python', 'Java'}.

# %%
# 2. Type Conversion Practice: 
# Convert a float to an integer, and explain what happens to the decimal part.

a = 40.56 # it's only returns the complete number and remove the decimal part.
int(a)
# Out:
# 40

# %% [raw]
# o Create a list of integers and:
#  Append a new number.
#  Insert a number at a specific index.
#  Remove duplicates and print the final list.

# %%
a = [10,20,30,40,50]
a.append(60)
a
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.insert(2,20)
a
# Out:
# [10, 20, 20, 25, 30, 40, 50, 60]

# %%
a = list(set(a))
print(a)
# Out:
# [40, 10, 50, 20, 60, 30]

# %% [raw]
# Tuple Manipulation:
# o Define a tuple of 5 colors.
# o Try to add a new color to the tuple (observe and explain why it fails).
# o Convert the tuple to a list, add the color, and convert it back to a tuple.

# %%
t = ('red','pink','yellow','navyblue','black')
t
# Out:
# ('red', 'pink', 'yellow', 'navyblue', 'black')

# %%
t = list(t)
t
# Out:
# ['red', 'pink', 'yellow', 'navyblue', 'black']

# %%
t.append('Rosepink')
t
# Out:
# ['red', 'pink', 'yellow', 'navyblue', 'black', 'Rosepink']

# %%
t = set(t)
t
# Out:
# {'Rosepink', 'black', 'navyblue', 'pink', 'red', 'yellow'}

# %% [raw]
# Set Operations:
# o Create two sets of random numbers.
# o Find and print their union, intersection, and difference.
# o Remove one element from the first set and add a new element.

# %%
a = {1,2,3,3,5,6,6,7}
b = {1,6,7,8,3,3,4,9}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a.intersection(b)
# Out:
# {1, 3, 6, 7}

# %%
a.pop()
# Out:
# 1

# %%
a
# Out:
# {2, 3, 5, 6, 7}

# %%
a.add(20)

# %%
a
# Out:
# {2, 3, 5, 6, 7, 20}

# %% [raw]
# Dictionary Practice:
# o Define a dictionary for a library system with book titles as keys and available
# copies as values.
# o Update the count of a specific book after it is borrowed.
# o Add a new book to the dictionary and print the updated dictionary.

# %%
library = {'The hobbit':30,'rich dad poor dad':20,'great Expectation':12}
library
# Out:
# {'The hobbit': 30, 'rich dad poor dad': 20, 'great Expectation': 12}

# %%
library['The hobbit'] = library['The hobbit'] -1
library
# Out:
# {'The hobbit': 27, 'rich dad poor dad': 20, 'great Expectation': 12}

# %%
library['Animal Farm'] = 20
library
# Out:
# {'The hobbit': 27,
#  'rich dad poor dad': 20,
#  'great Expectation': 12,
#  'Animal Farm': 20}
