# %%
# Part A: Slicing Basics (Forward & Backward)
# Question 1

l = [10, 20, 30, 40, 50, 60, 70, 80]
l[2:5]
# Out:
# [30, 40, 50]

# %%
# Question 2

l[:4]  # start from the starting to the end index 4.
# Out:
# [10, 20, 30, 40]

# %%
# Question 3

l[5:] # start index is 5 to till end.
# Out:
# [60, 70, 80]

# %%
# Question 4

l[::2] # get every second element.
# Out:
# [10, 30, 50, 70]

# %%
# Question 5

l[::-1] # to get all the list element from the end.
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
#Question 6

l[-4:-1] # return the element whose place value in betwwen the -4 to -1.
# Out:
# [50, 60, 70]

# %%
#Question 7

l[6:1:-2] # to print the list from 6 to 1 with reverse order also get the every sencond element.
# Out:
# [70, 50, 30]

# %%
# Question 8
l[-3:]  # to get the last three element from the list.
# Out:
# [60, 70, 80]

# %%
# Question 9
nested = [1, 2, [100, 200, [300, 400]], 5]
nested.index([100,200,[300,400]])  # it shows the index value of the sub-list in given list.
# Out:
# 2

# %%
# Question 10
nested[2][1] # access the 200
# Out:
# 200

# %%
# Question 11
nested[2][2][1] # access the 400
# Out:
# 400

# %%
# Question 12
nested[2][1] = 250  # this make change the list and change the 200 with the 250.
print(nested)
# Out:
# [1, 2, [100, 250, [300, 400]], 5]

# %%
# Question 13
nested[2][0:2] # [2]:- for the sub-list which start at index value 2
# Out:
# [100, 250]

# %%
# Question 14
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
data[1]
# Out:
# [4, 5, 6]

# %%
# Question 15
data[1][1:3]
# Out:
# [5, 6]

# %%
# Question 16
data[-1][-1]
# Out:
# 9

# %%
# Question 17
#If x = [1, 2, 3], what is the difference between x.append([4, 5]) and x.extend([4, 5])?

x = [1, 2, 3]
x.append([4, 5]) # add the element as it is 
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1, 2, 3]
x.extend([4, 5]) # add the element by saperating them
x
# Out:
# [1, 2, 3, 4, 5]

# %%
# Question 18
# if z = [10, 20, 50, 76, 89, 56, 87, 90]. What is z[-3::-1]?

z = [10, 20, 50, 76, 89, 56, 87, 90]
z[-3::-1]  # from the index -3  to till the end with jump size -1.
# Out:
# [56, 89, 76, 50, 20, 10]

# %%
# Question 19
# Write code to reverse only the middle three elements of a 5-element list.

l = [1, 2, 3, 4, 5]
l[1:4] = l[1:4][::-1] # To print the middle three elements in reverce order.
print(l)
# Out:
# [1, 4, 3, 2, 5]

# %%
# Question 20
# Create a nested list where the first element is a string, and the second element is a slice of [1, 2, 3, 4, 5].
n = ['hello']
a = [1,2,3,4,5]
n.insert(1,a[1:3])
n
# Out:
# ['hello', [2, 3]]
