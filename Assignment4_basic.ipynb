# %%
# 1. How would you convert one data type to another in Python? For example, an integer to a string. 
# Solution : Using the Typecasting 

a = 5
str(a)
# Out:
# '5'

# %%
# 2. What is the difference between == and = in Python? 
# Solution : 

a = 5 # To assign the value 5 to the variable a and b
b = 5
a == b # To compare the value
# Out:
# True

# %%
# 3. How does the modulus operator (%) work in Python? 
# Solution: It return the remainder  

a = 30
b = 5
a % b
# Out:
# 0

# %%
a = 20
b = 3
a % b
# Out:
# 2

# %%
# 4.What will be the output of 3 * "Hello" in Python? Explain why.
# Solution : Here Hello appear three time because we multiple it 3 times.

a = 3 * 'Hello'
print(a)
# Out:
# HelloHelloHello

# %%
# 5. What is string concatenation, and how would you do it in Python? 
# Solution : To add the to string

name = 'Renuka'
surname = 'Patil'
full_name = name + surname 
print(full_name)
# Out:
# RenukaPatil

# %%
name = 'Renuka'
surname = 'Patil'
full_name = name +" " + surname  # To add the space between the name and surname.
print(full_name)
# Out:
# Renuka Patil
