# %%
# Question No. 1

# Task --> To extract the target from the list..

data = ["a", "b",["c",["d","e","target"],"f"],"g"]  
data[2][1][2]
# Out:
# 'target'

# %%
# Question No. 2

# Task A --> Add the ['green', 'yellow'] so the result is ['red','blue',['green','yellow']].

colors = ['red', 'blue']
colors.append(['green', 'yellow'])
print(colors)
# Out:
# ['red', 'blue', ['green', 'yellow']]

# %%
# Question No. 2

# Task B --> Add the same list so the result is ['red', 'blue', 'green', 'yellow'].

colorsb = ['red', 'blue']
colorsb.extend(['green', 'yellow'])
print(colorsb)
# Out:
# ['red', 'blue', 'green', 'yellow']

# %%
# Quetion No. 3

# Task --> Access the number 6 from given list.

matrix = [[1,2,3],[4,5,6],[7,8,9]]
matrix[1][2]
# Out:
# 6

# %%
# Question No. 4

# Task --> Insert the number 30 at the correct spot to keep the list numerical.

nums = [10, 20, 40]
nums.insert(2, 30)
print(nums)
# Out:
# [10, 20, 30, 40]

# %%
# Question No. 5

# Task --> Change the False to None.

mixed = [1, 'python', [True, False]]
mixed[2][1] = None
print(mixed)
# Out:
# [1, 'python', [True, None]]

# %%
# Question No. 6

# Accessing Triple-Nested Items..

nested = [1,[2,3,[4,5,6]],7]

nested[1][0] # Access the 2.
# Out:
# 2

# %%
nested[1][2] # Accessing the [4,5,6].
# Out:
# [4, 5, 6]

# %%
nested[1][2][1] # Accessing the 5.
# Out:
# 5

# %%
# Question No. 7

matrix = [[10,20,30],[40,50,60],[70,80,90]]
matrix[1] # Access the middle row.
# Out:
# [40, 50, 60]

# %%
matrix[2][2]  # Access the 90.
# Out:
# 90

# %%
matrix[1][0] # Access the 40.
# Out:
# 40

# %%
# Practice Challenges

# 1. : What is the output of l[2][1] if l = [5, 6, [7, 8, 9], 10]?

l = [5, 6, [7, 8, 9], 10]
l[2][1]
# Out:
# 8

# %%
# 2. : If data = [1, 2], what does data.extend([3, [4, 5]]) produce?

data = [1, 2]
data.extend([3, [4, 5]])
print(data)
# Out:
# [1, 2, 3, [4, 5]]

# %%
# 3. : How do you change 'hello' to 'hi' in x = [10, [20, 'hello']]?

x = [10, [20, 'hello']]
x[1][1] = 'hi'
print(x)
# Out:
# [10, [20, 'hi']]

# %%
# 4. : Given vals = [1, 2, 3], what is the result of vals.insert(0, [0])?

vals = [1, 2, 3]
vals.insert(0, [0])  # vals.insert(0, [0]) insert the [0] on the index 0.
print(vals)
# Out:
# [[0], 1, 2, 3]

# %%
# 5. : Given a = [1, 2] and b = [3, 4], what is a.append(b) followed by len(a)?

a = [1, 2]
b = [3, 5]
a.append(b)   # this result is [1, 2, [3, 5]] with the length is 3.
print(a)
# Out:
# [1, 2, [3, 5]]

# %%
len(a)
# Out:
# 3
